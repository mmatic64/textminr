# %% [markdown]
# # Wikipedia search

# %% [markdown]
# ### Testing of the wikipedia package

# %%
import wikipedia

author = "Johann Wolfgang von Goethe"
title = "Torquato Tasso Schauspiel"
old_date = 1749 

wikipedia.set_lang("de")

search = wikipedia.search(author)
print(type(search))

found = []
for s in search:
    wiki = wikipedia.page(s).content
    for t in title.split(" "):
        if t in wiki:
            found.append(wiki)
            print("Search: " + s)
            print("Word in Text: " + t)
            break

margin = 100
n = -1
for f in found:
    for t in title.split(" "):
        n = f.find(s)
        if n == -1:
            continue
        else:
            print(t)
            break
    text_to_check = f[n-margin:n+margin]
    print("text (" + str(n) + "): " + text_to_check + "\n")
# Out:
# <class 'list'>
# Search: Johann Wolfgang von Goethe
# Word in Text: Torquato
# Search: Götz von Berlichingen (Goethe)
# Word in Text: Schauspiel
# Search: Wolfgang Goethe
# Word in Text: Torquato
# Search: Friedrich Schiller
# Word in Text: Schauspiel
# Torquato
# text (122266): ia hatte zwei Kinder (Nichten Goethes), deren Nachkommen (Linie Nicolovius) noch heute leben. Siehe Goethe (Familie).
# Goethe hatte seine drei Enkel als Universalerben eingesetzt. Als Überlebender der
#
# text (-1):
#
# Torquato
# text (122266): ia hatte zwei Kinder (Nichten Goethes), deren Nachkommen (Linie Nicolovius) noch heute leben. Siehe Goethe (Familie).
# Goethe hatte seine drei Enkel als Universalerben eingesetzt. Als Überlebender der
#
# text (-1):

# %% [markdown]
# # Get all the data from the wikipedia

# %%
import wikipedia
import requests
from bs4 import BeautifulSoup
import random

# Infrmation of the book
author = "Theodor Fontane"
title = "Jenny Treibel Roman Berliner Gesellschaft"
old_date = 1828 

wikipedia.set_lang("de")

# Search for the possible wiki-websites about the author
search = wikipedia.search(author)

# Function to get the html of the author, for easier usage in the for loop
def gethtmlbyauthor(author):
	response = requests.get(
		url="https://de.wikipedia.org/wiki/" + author,
	)
	return response

# the content of the websites that include a part of the title of the book
found = []
for s in search:
    # replace the spaces with the _ so it can be used in the url
    s.replace(" ", "_")
    response = gethtmlbyauthor(s)
    soup = BeautifulSoup(response.content, 'html.parser')
    # get the content of the website
    content = soup.find_all('div', class_='mw-content-ltr').__str__()
    for t in title.split(" "):
        # check if a part of the title is in the content of the website
        if t in content:
            # add the content to the found list
            found.append(content)
            # print the deatils of the search
            print("Search: " + s + "\nWord in Text: " + t)
            break

print()

margin = 200
n = -1
# list to store the found sentences with the title
text = []
for f in found:
    # look for the position of the title in the content
    for t in title.split(" "):
        n = f.find(t)
        if n == -1:
            continue
        else:
            print(t)
            break
    # get the sentence and text around the title
    text_to_check = f[n-margin:n+margin]
    # print the sentence
    print("text (" + str(n) + "): " + text_to_check + "\n")
    # add the sentence to the list
    text.append(text_to_check)
# Out:
# Search: Theodor Fontane
# Word in Text: Jenny
# Search: Theodor Storm
# Word in Text: Jenny
# Search: Effi Briest
# Word in Text: Jenny
# Search: Fontane
# Word in Text: Roman
# Search: Neuruppin
# Word in Text: Berliner
# Search: Medizinische Hochschule Brandenburg Theodor Fontane
# Word in Text: Gesellschaft
# Search: Wanderungen durch die Mark Brandenburg
# Word in Text: Jenny
# Search: Theodor Fontane-Arbeitsstelle
# Word in Text: Gesellschaft
#
# Jenny
# text (71046): tane&amp;rft.btitle=Unwiederbringlich&amp;rft.date=1892&amp;rft.genre=book&amp;rft.place=Berlin&amp;rft.pub=Verlag+Wilhelm+Hertz"> </span></li>
# <li><cite style="font-style:italic"><a href="/wiki/Frau_Jenny_Treibel" title="Frau Jenny Treibel">Frau Jenny Treibel</a> oder „Wo sich Herz zum Herzen find’t.“ Roman</cite>. Verlag F. Fontane &amp; Co., Berlin 1893 (<a class="external text" href="http://ar
#
# Jenny
# text (132398): p class="reference" id="cite_ref-153"><a href="#cite_note-153">[153]</a></sup> Seinen Eltern schrieb er 1855 aus Potsdam von freundlichen „pferdehändlerische(n) Juden“ und erwähnte ein Mädchen namens Jenny, dem sein Sohn Ernst den Namen „die schwarze Jenningerin“ gegeben hatte.
# Auch in <a href="/wiki/Heilbad_Heiligenstadt" title="Heilbad Heiligenstadt">Heiligenstadt</a> gab es eine jüdische Gemein
#
# Jenny
# text (140280): tine (Fontane)">Stine</a> |
# <a href="/wiki/Quitt_(Fontane)" title="Quitt (Fontane)">Quitt</a> |
# <a href="/wiki/Unwiederbringlich" title="Unwiederbringlich">Unwiederbringlich</a> |
# <a href="/wiki/Frau_Jenny_Treibel" title="Frau Jenny Treibel">Frau Jenny Treibel</a> |
# <a href="/wiki/Meine_Kinderjahre" title="Meine Kinderjahre">Meine Kinderjahre</a> |
# <a class="mw-selflink selflink">Effi Briest</a> |
#
# Roman
# text (1172): ), deutscher Apotheker, Vater von Theodor Fontane</li>
# <li><a href="/wiki/Martha_Fontane" title="Martha Fontane">Martha Fontane</a> (1860–1917), Tochter von Theodor Fontane und Urbild mehrerer seiner Romanfiguren</li>
# <li>Mete Fontane, siehe <a href="/wiki/Martha_Fontane" title="Martha Fontane">Martha Fontane</a></li>
# <li><a href="/wiki/Otto_Fontane" title="Otto Fontane">Otto Fontane</a> (1887–195
#
# Berliner
# text (54431): itle="Wiekhaus">Wiekhäuser</a> und zwei hohe Türme verstärkten die <a href="/wiki/Stadtmauer" title="Stadtmauer">Stadtmauern</a>. Dazu kamen drei Tore, das Altruppiner/Rheinsberger Tor im Norden, das Berliner/Bechliner Tor im Süden und das Seetor im Osten. Die vollständige Ummauerung erfolgte spätestens gegen Ende des 15. Jahrhunderts.
# </p><p>Neuruppins ältester Teil war ein langgestreckter Anger,
#
# Gesellschaft
# text (20918): ten: Träger"><span>Quelltext bearbeiten</span></a><span class="mw-editsection-bracket">]</span></span></div>
# <p>Trägergesellschaft der Hochschule ist die Medizinische Hochschule Campus <a href="/wiki/Gesellschaft_mit_beschr%C3%A4nkter_Haftung_(Deutschland)" title="Gesellschaft mit beschränkter Haftung (Deutschland)">GmbH</a>. Die Beteiligungen an dieser verteilen sich seit der Gründung der Hochsch
#
# Jenny
# text (98260): tine (Fontane)">Stine</a> |
# <a href="/wiki/Quitt_(Fontane)" title="Quitt (Fontane)">Quitt</a> |
# <a href="/wiki/Unwiederbringlich" title="Unwiederbringlich">Unwiederbringlich</a> |
# <a href="/wiki/Frau_Jenny_Treibel" title="Frau Jenny Treibel">Frau Jenny Treibel</a> |
# <a href="/wiki/Meine_Kinderjahre" title="Meine Kinderjahre">Meine Kinderjahre</a> |
# <a href="/wiki/Effi_Briest" title="Effi Briest">E
#
# Gesellschaft
# text (13017): um Berlin verfügt über einen großen Fontane-Nachlass)</li>
# <li><a href="/wiki/Theodor-Fontane-Archiv" title="Theodor-Fontane-Archiv">Theodor-Fontane-Archiv</a></li>
# <li><a href="/wiki/Theodor_Fontane_Gesellschaft" title="Theodor Fontane Gesellschaft">Theodor Fontane Gesellschaft</a></li></ul>
# <div class="mw-heading mw-heading2"><h2 id="Publikationen">Publikationen</h2><span class="mw-editsection">

# %% [markdown]
# # Clear the found text of any html

# %%
def clear_text(text):
    # removes the first part if it already starts within a html tag
    if text.find(">") < text.find("<"):
        text = text[text.find(">")+1:]

    html = False
    i = 0
    while i < len(text):
        if text[i] == '<':
            html = True
        # if inside a html tag, remove the character
        if html:
            if text[i] == '>':
                html = False
                text = text[:i] + "  " + text[i+1:]
            else:
                text = text[:i] + text[i+1:]
                i -= 1
        i += 1
    return text

for i in range(0,len(text)):
    text[i] = clear_text(text[i])
    print(text[i] + "\n")
# Out:
#
#       Frau Jenny Treibel   oder „Wo sich Herz zum Herzen find’t.“ Roman  . Verlag F. Fontane &amp; Co., Berlin 1893 (
#
#   [153]     Seinen Eltern schrieb er 1855 aus Potsdam von freundlichen „pferdehändlerische(n) Juden“ und erwähnte ein Mädchen namens Jenny, dem sein Sohn Ernst den Namen „die schwarze Jenningerin“ gegeben hatte.
# Auch in   Heiligenstadt   gab es eine jüdische Gemein
#
# Stine   |
#   Quitt   |
#   Unwiederbringlich   |
#   Frau Jenny Treibel   |
#   Meine Kinderjahre   |
#   Effi Briest   |
#
# ), deutscher Apotheker, Vater von Theodor Fontane
#     Martha Fontane   (1860–1917), Tochter von Theodor Fontane und Urbild mehrerer seiner Romanfiguren
#   Mete Fontane, siehe   Martha Fontane
#     Otto Fontane   (1887–195
#
# Wiekhäuser   und zwei hohe Türme verstärkten die   Stadtmauern  . Dazu kamen drei Tore, das Altruppiner/Rheinsberger Tor im Norden, das Berliner/Bechliner Tor im Süden und das Seetor im Osten. Die vollständige Ummauerung erfolgte spätestens gegen Ende des 15. Jahrhunderts.
#     Neuruppins ältester Teil war ein langgestreckter Anger,
#
#   Quelltext bearbeiten      ]
#   Trägergesellschaft der Hochschule ist die Medizinische Hochschule Campus   GmbH  . Die Beteiligungen an dieser verteilen sich seit der Gründung der Hochsch
#
# Stine   |
#   Quitt   |
#   Unwiederbringlich   |
#   Frau Jenny Treibel   |
#   Meine Kinderjahre   |
#   E
#
# um Berlin verfügt über einen großen Fontane-Nachlass)
#     Theodor-Fontane-Archiv
#     Theodor Fontane Gesellschaft
#     Publikationen

# %% [markdown]
# # The model that searches for the year in the found sentences

# %%
model_id = 'textminr/ner-multilingual-bert'

from transformers import pipeline
classifier = pipeline(
  'ner',
  model=model_id,
  aggregation_strategy='simple'
)

k = []
for i in range(len(text)):
    # model looks for the correct date in the text
    k.append(classifier(text[i]))
    print(str(i) + ":")
    # only the dates are printed, because the model also looks for other entities
    for c in k[i]:
       if c['entity_group'] == 'DATE':
          print(c)
# Out:
# AUTHOR
# 0:
# {'entity_group': 'DATE', 'score': 0.9917932, 'word': '1893', 'start': 117, 'end': 121}
# 1:
# {'entity_group': 'DATE', 'score': 0.85653, 'word': '1855', 'start': 37, 'end': 41}
# 2:
# 3:
# {'entity_group': 'DATE', 'score': 0.93120223, 'word': '1860', 'start': 74, 'end': 78}
# {'entity_group': 'DATE', 'score': 0.9253216, 'word': '1917', 'start': 79, 'end': 83}
# {'entity_group': 'DATE', 'score': 0.73329353, 'word': '1887', 'start': 219, 'end': 223}
# 4:
# 5:
# 6:
# 7:
